# %% [markdown]
# <a href="https://colab.research.google.com/github/azhar2929/Capstone-project--EDA/blob/main/Capstone_Project_Exploratory_Data_Analysis_(Azhar).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member  -**  Azharuddin Hussain Mirza

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Airbnb is an online marketplace that connects people who want to rent out their homes with people who are looking for accommodations in specific locales.
# It has revolutionized the hospitality industry, as  travelers would have booked a hotel or hostel for their trip to another town.
# Airbnb offers people an easy, relatively stress-free way to earn some income from their property.It has certain regulations that are designed to protect both guests and hosts.
# The platform provides a user-friendly interface where hosts can create listings, including detailed descriptions, photos, and pricing information for their properties. Guests can then browse these listings, read reviews from previous visitors, and make bookings directly through the Airbnb website or mobile app. Airbnb is cheaper than hotel because the owners of these rentals don’t have the same overhead costs as hotels.
#
# In this project we analyze all the columns which gave us the information about customers , room prices,their locations and many more important visuallization.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Since 2008 guest and hosts used airbnb to expand on travelling possibilities and present a more unique personalized way of experiencing the world.Today Airbnb become one of a kind service that is used and recignize by the whole world. Data analysis on millions of listing provided through airbnb is a crucial factor for the company. These millions of generating the lot of data - data that can be analyzed and used for security business discussion, understanding the custommers and providers (host) behaviour and performance on the guiding marketing initiatives. Implementation on innovative additional services and much more. This dataset has arround 49000 observations in it with 16 columns and it is a mix of categorical and numerical values. Explore and analyze the data to discover key understandings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The agenda of airbnb as per bussiness objectives the important factor is of company success which means the revenue , productivity , growth etc.
# As increase in efficiency and accountibility in an organize way.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# all the libraries are imported !

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime as dt
plt.rcParams['figure.figsize'] = (10, 7)

# %% [markdown]
# ### Dataset Loading

# %%
# google drive has been mounted!

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
read ='/content/drive/MyDrive/DATA/Airbnb NYC 2019.csv'
airbnb = pd.read_csv(read)
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Dataset First View

# %%
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
airbnb.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
airbnb.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
airbnb.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
pd.set_option('display.max_rows', None)
plt.figure(figsize=(8,4))
sns.heatmap(airbnb.isnull(), cbar=False)
plt.show()

# %%
airbnb.groupby(['last_review']).count()
# Out:
#                id  name  host_id  host_name  neighbourhood_group  \
# last_review
# 2011-03-28      1     1        1          1                    1
# 2011-04-25      1     1        1          1                    1
# 2011-05-12      1     1        1          1                    1
# 2011-09-18      1     1        1          1                    1
# 2011-09-19      1     1        1          1                    1
# 2011-12-10      1     1        1          1                    1
# 2011-12-28      1     1        1          1                    1
# 2012-01-02      1     1        1          1                    1
# 2012-01-03      1     1        1          1                    1
# 2012-05-29      1     1        1          1                    1
# 2012-06-07      1     1        1          1                    1
# 2012-06-22      1     1        1          1                    1
# 2012-07-11      2     2        2          2                    2
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
#  I used to know about the dataset :-
#
# Id : Unique id
#
# Name : Name of the listing
#
# Host_id : unique host id
#
# Host_name : name of the host
#
# Neighbourhood_group :location
#
# neighbourhood : area
#
# latitude : latitude range
#
# longitude : longitude range
#
# room_type : types of rooms
#
# price : price of listing
#
# minimum_nights : minimum nights to be paid for
#
# Number_of_reviews : number of reviews
#
# Last_reviews : content of the last review
#
# review_per_month : number of checks per month
#
# calculate_host_listing_count : total count
#
# availability_365 : available round the year

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# In this dataset we have 16 columns and 48895 rows.
#
#   columns - ('id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365')

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

print(f"The unique value of id = {airbnb['id'].nunique()}")
print(f"The unique value of name = {airbnb['name'].nunique()}")
print(f"The unique value of host_id = {airbnb['host_id'].nunique()}")
print(f"The unique value of host_name = {airbnb['host_name'].nunique()}")
print(f"The unique value of neighbourhood_group = {airbnb['neighbourhood_group'].nunique()}")
print(f"The unique value of neighbourhood  = {airbnb['neighbourhood'].nunique()}")
print(f"The unique value of latitude = {airbnb['latitude'].nunique()}")
print(f"The unique value of longitude = {airbnb['longitude'].nunique()}")
print(f"The unique value of room_type = {airbnb['room_type'].nunique()}")
print(f"The unique value of price = {airbnb['price'].nunique()}")
print(f"The unique value of minimum_nights = {airbnb['minimum_nights'].nunique()}")
print(f"The unique value of number_of_reviews = {airbnb['number_of_reviews'].nunique()}")
print(f"The unique value of last_review = {airbnb['last_review'].nunique()}")
print(f"The unique value of reviews_per_month = {airbnb['reviews_per_month'].nunique()}")
print(f"The unique value of calculated_host_listings_count = {airbnb['calculated_host_listings_count'].nunique()}")
print(f"The unique value of availability = {airbnb['availability_365'].nunique()}")
# Out:
# The unique value of id = 48895
# The unique value of name = 47905
# The unique value of host_id = 37457
# The unique value of host_name = 11452
# The unique value of neighbourhood_group = 5
# The unique value of neighbourhood  = 221
# The unique value of latitude = 19048
# The unique value of longitude = 14718
# The unique value of room_type = 3
# The unique value of price = 674
# The unique value of minimum_nights = 109
# The unique value of number_of_reviews = 394
# The unique value of last_review = 1764
# The unique value of reviews_per_month = 937
# The unique value of calculated_host_listings_count = 47
# The unique value of availability = 366

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

airbnb.reviews_per_month.fillna(value=0, inplace= True)
airbnb['last_review'] = pd.to_datetime(airbnb['last_review'],format='%Y-%m-%d')
airbnb.last_review = airbnb['last_review'].dt.year.astype('object')
airbnb.last_review.fillna(value = 'never', inplace=True)

# %%
airbnb.dropna(inplace=True)
airbnb.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# We just replace the null values to '0' in a reviews_per_month and also replace the null values to 'never' in a last_review as it affect the visualizations charts , we alse sort last_review into datetime format and after that we simply remove all the duplicates.

# %% [markdown]
# ## ***4. Data visualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1
#   **(Types of room type according to locations)**

# %%
#what is the average prefered price by customer according to the location

avg_price=airbnb.groupby(['neighbourhood_group','room_type'],as_index=False)[ 'price'].mean().rename(columns={'neighbourhood_group':'location', 'price':'avg_price'})
avg_price
# Out:
#          location        room_type   avg_price
# 0           Bronx  Entire home/apt  127.645503
# 1           Bronx     Private room   66.788344
# 2           Bronx      Shared room   58.610169
# 3        Brooklyn  Entire home/apt  178.362609
# 4        Brooklyn     Private room   76.510619
# 5        Brooklyn      Shared room   50.527845
# 6       Manhattan  Entire home/apt  249.238211
# 7       Manhattan     Private room  116.805594
# 8       Manhattan      Shared room   88.977083
# 9          Queens  Entire home/apt  147.050573
# 10         Queens     Private room   71.776855
# 11         Queens      Shared room   69.020202
# 12  Staten Island  Entire home/apt  173.846591
# 13  Staten Island     Private room   62.292553
# 14  Staten Island      Shared room   57.444444

# %%
avg_price1 = airbnb.groupby(['neighbourhood_group','room_type'])[ 'price'].mean().unstack()
avg_price1
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     127.645503     66.788344    58.610169
# Brooklyn                  178.362609     76.510619    50.527845
# Manhattan                 249.238211    116.805594    88.977083
# Queens                    147.050573     71.776855    69.020202
# Staten Island             173.846591     62.292553    57.444444

# %%
avg_price1.plot.bar()
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Answer Here** :- To show the relation between the entire neighbourhood_group and room_type accordingly average price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer Here :-** As shown in the above chart the  maximum average price values is of entire home/apartment at manhattan and minimum average price of shared room  at brooklym location.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *Answer* **Here** :- Yes,it is possible to gain insights. for example if i will increase the quantity of entire rooms as compared to others, after that insight automatically will be increased.
#
# as shown in the chart the neighbourhood_group not so much prefered the shared rooms  as compared to others room types.

# %% [markdown]
# #### Chart - 2
#   **(Minimum nights spend on location)**

# %%
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Chart - 2 visualization code

night_spent = airbnb.groupby('neighbourhood_group',as_index=True)['minimum_nights'].sum().reset_index().rename(columns={'neighbourhood_group': 'location'})
night_spent
# Out:
#         location  minimum_nights
# 0          Bronx            4971
# 1       Brooklyn          121693
# 2      Manhattan          184792
# 3         Queens           29356
# 4  Staten Island            1802

# %%
sns.set_style('dark')
sns.barplot(night_spent, x= 'location', y = 'minimum_nights')
plt.title('Nights_spent on the location')
plt.xlabel('location')
plt.ylabel('minimum_nights')
# Out:
# Text(0, 0.5, 'minimum_nights')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# TO show the relation between location and minimum nights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As per the barplot charts the maximum nights spend at the location of manhattan and minimum night spend at the location of staten island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes , it is gained insights on the location of manhattan as it is most popular place where the most customers are spending their nights,it created a positive growth our bussiness.
#
# In 'staten island' and 'bronex' location  customers spending their minimum nights to show the negative impact.

# %% [markdown]
# #### Chart - 3
#
#   **(Most preferred room)**

# %%
airbnb['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
new = airbnb.groupby('room_type')['minimum_nights'].sum().reset_index()
sorted = new.sort_values('minimum_nights', ascending=True)
sorted
# Out:
#          room_type  minimum_nights
# 2      Shared room            7510
# 1     Private room          120023
# 0  Entire home/apt          215081

# %%
labels=list(sorted['room_type'])
sizes=list(sorted['minimum_nights'])
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.title('Most preferred rooms',fontsize=20)
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In a pie charts , it quickly show the in the form of percentage how many nights spend by the customers based on the room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As compared to all the others room types 62.8% of customers loved to spending their nights in entire home,35% in private room and only 2.2% in shared room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes , it is gained insights on the room type of entire home/apt which is most popular among customers.
#
# In 'shared rooms' we lead to negative growth as the  customers spending their minimum nights only 2.2%.

# %% [markdown]
# #### Chart - 4
#
#   **(Best location review)**

# %%
# Chart - 4 visualization code

best_location= airbnb.groupby( 'neighbourhood_group',as_index=False)[ 'number_of_reviews'].sum().reset_index().rename(columns={'neighbourhood_group':'location'})
max_reviews=best_location.sort_values(['number_of_reviews'],ascending=False)
max_reviews
# Out:
#    index       location  number_of_reviews
# 1      1       Brooklyn             486174
# 2      2      Manhattan             454126
# 3      3         Queens             156902
# 0      0          Bronx              28334
# 4      4  Staten Island              11541

# %%
sns.barplot(x='location',y='number_of_reviews',data=max_reviews)
plt.title("best_location_review")
# Out:
# Text(0.5, 1.0, 'best_location_review')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It quickly shows relation between the number of reviews according to their locations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this chart we simply see the location of brooklyn is attemped the higher number of reviews as compared to others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it is because when the customers comes our website they firstly see the reviews for better satisfaction.'brooklyn' location shows the maximum number of reviews for positive business impact.
#
# As per location minimum reviews got the 'staten island' and 'bronx' it shows the negative impact for us.

# %% [markdown]
# #### Chart - 5
#
#   **(Average price of Location)**

# %%
# Chart - 5 visualization code

prices= airbnb.groupby('neighbourhood_group',as_index=False)['price'].mean().reset_index().rename(columns={'neighbourhood_group':'location'})
highest_price=prices.sort_values(['price'],ascending=False)
highest_price
# Out:
#    index       location       price
# 2      2      Manhattan  196.897473
# 1      1       Brooklyn  124.410523
# 4      4  Staten Island  114.812332
# 3      3         Queens   99.536017
# 0      0          Bronx   87.469238

# %%
#create datasets
labels=list(highest_price['location'])
#choose the size
sizes=list(highest_price['price'])
#choose the colors
colors=['orange','skyblue','red','green','yellow']
#create the explodes
explode=(0.07,0.07,0.07,0.07,0.07)

# %%
plt.pie(sizes,explode=explode,labels=labels, colors=colors,autopct='%1.1f%%')
plt.title('Average price of location',fontsize=(20))
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It directly show the average price based on their locations in the form of percentage.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Manhatten location shows 31.6% of
#     average price.
# *   brooklyn location shows 20% of average
#     price.
# *   staten island shows 18.4% of average
#     price
# *   queen location shows 16% of average
#     price.
# *    bronx location shows 14% of average
#     price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The maximum average price has taken by manhatten location which means customer loved to visit most of it that shows the positive impact.
#
# The negative growth show as per pie charts the location of 'bornx' is getting very low average price as compared to others.

# %% [markdown]
# #### Chart - 6
#
#   **(Relationship between neighbourhood_group and availability_365)**

# %%
# Chart - 6 visualization code
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
plt.figure(figsize=(10,4))
a= sns.boxplot(airbnb, x= 'neighbourhood_group', y='availability_365', palette = 'plasma' )
a.set_title('Relationship between neighbourhood_group and availability_365 ')
# Out:
# Text(0.5, 1.0, 'Relationship between neighbourhood_group and availability_365 ')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It quickly shows the relationship between neighbourhood_group and availability_365.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# staten island has the highest number of rooms which are in availability_365.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# as per boxplot charts, staten island has the highest number of available rooms thats shows the positive impact for business and customers also.
#
# Location of 'Brooklyn' and 'Manhatten' has the very low avaibility of room as compared to others this will shows the negative growth for business growth.

# %% [markdown]
# #### Chart - 7
#
#   **(No of host_id as per location)**

# %%
# Chart - 7 visualization code
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
as_per_host_id = airbnb.groupby('neighbourhood_group')['host_id'].count()
as_per_host_id
# Out:
# neighbourhood_group
# Bronx             1089
# Brooklyn         20089
# Manhattan        21643
# Queens            5664
# Staten Island      373
# Name: host_id, dtype: int64

# %%
plt.plot(as_per_host_id)
plt.title('Number of host per location')
plt.ylabel('HOST')
plt.xlabel('LOCATION')
# Out:
# Text(0.5, 0, 'Location')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Its shows the trending host_id on the basis of locations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  we found that 'manhattan' and 'brooklyn' groups are highly active.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 'Manhattan' and 'Brookly' is the location where number of host_id are most active and growing their business this shows the positive impact.
#
# Negative impact is in a group of 'bronx' , 'queen' and 'staten island' location show very low activeness of host_id.

# %% [markdown]
# #### Chart - 8
#
#   **(Highest and Lowest minimum_nights stays by host id)**

# %%
airbnb.T
# Out:
#                                                              0      \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                  40.64749
# longitude                                                -73.97237
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                                 2018.0
# ...

# %%
categorical_data = airbnb[['id','host_name','number_of_reviews','neighbourhood_group','neighbourhood','price','room_type','minimum_nights','availability_365','reviews_per_month']].sort_values('minimum_nights',ascending=False)
categorical_data.head(5)
# Out:
#              id  host_name  number_of_reviews neighbourhood_group  \
# 5767    4204302  Genevieve                  2           Manhattan
# 26341  20990053      Angie                 24            Brooklyn
# 38664  30378211        Meg                  0           Manhattan
# 13404  10053943   Glenn H.                  2           Manhattan
# 11193   8668115      Laura                 10            Brooklyn
#
#            neighbourhood  price        room_type  minimum_nights  \
# 5767   Greenwich Village    180  Entire home/apt            1250
# 26341       Williamsburg     79     Private room             999
# 38664  Greenwich Village    110      Shared room             999
# 13404             Harlem     99  Entire home/apt             999
# 11193      Crown Heights     50     Private room             500
#
#        availability_365  reviews_per_month
# 5767                365               0.03
# 26341               249               1.12
# 38664               365               0.00
# ...

# %%
plt.figure(figsize=(18,6))
plt.title('highest minimum nights stay requirement by host name')
sns.barplot(data=categorical_data.head(25),x='host_name',y='minimum_nights',hue='neighbourhood_group');

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plot shows the relationship between the host_name and minimum_nights

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here Genevieve, Peter, Meg, Angie, etc are those host who only want to attract only long term guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Here we can see from reviews per month that the frequency of visits of listing is less for long term minimum nights.
# As Manhattan neighbourhood_group has maximum minimum_nights which leads to the bussiness growth.
# Bronx neighbourhood_group has lowest number of nights which leads to negative growth.

# %% [markdown]
# #### Chart - 9
#
#   **(Longitude and Latitude wide range)**

# %%
# Chart - 9 visualization code
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(airbnb['neighbourhood_group'] , x = airbnb['latitude'],  y = airbnb['longitude'] , hue = airbnb['neighbourhood_group'] )
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It shows the relationship between longitude and latitude according to their neighbourhood_group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we shows in this chart wide distribution of queens which lies between latitude range of 40.5 to 40.8 and longitude range of -74.0 to -73.7.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# we have seen in the chart 'queens' of neighbourhood_group which has very maximum wide range of latitude and longitude which shows the positive business impact.
#
# As in location of 'manhattan' and 'staten island' which has minimum wide range of longitude and latitude shows the negative impact.

# %% [markdown]
# #### Chart - 10

# %%
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Chart - 10 visualization code

plt.title('Counts of availability_365')
sns.histplot(airbnb , x = 'availability_365', kde = True)
# Out:
# <Axes: title={'center': 'Counts of availability_365'}, xlabel='availability_365', ylabel='Count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the counts of the availability_365.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found from the chart that approx 0-20 days have maximum number of counts which shows availability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We see in this chart that 0-20 days by host for booking is maximum in which it create a positive business impact .

# %% [markdown]
# #### Chart - 11 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
sns.heatmap(data = airbnb.corr(), annot = True, cmap='BuPu')
# Out:
# <ipython-input-53-da7d297e792d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data = airbnb.corr(), annot = True, cmap='BuPu')
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  The heatmap chart quickly show the correlation between two variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Above data analysis shows that their is a strong relation between data of  number_of_reviews and reviews_per_month.

# %% [markdown]
# #### Chart - 12 - Pair Plot

# %%
# Pair Plot visualization code
plt.figure(figsize=(12,12))
pp = airbnb[['number_of_reviews','neighbourhood_group', 'room_type' , 'price','minimum_nights','availability_365','reviews_per_month']]
sns.pairplot(pp,hue='room_type');

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Seaborn Pairplot allows us to plot pairwise relationships between variables within a dataset. This creates a nice visualisation and helps us understand the data by summarising a large amount of data in a single figure.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above charts shows that
#
#
#
# * No_of_reviews vs price : we can see from above pairplot that as the price increases number of reviews decreases. and the lower price = higher number of reviews. highest number of reviews are getting by the listing . also highest
# number of reviews is getting by the listing of private room type.
#
# * Minimum_nights vs price: most host whose requirement of minimum night is high they prefer to put less price range.
#
# * reviews per month vs price: we can see that, highest frequency of visit i.e. high reviews per month = where there is less price.
#
# * reviews per month vs minimum nights: from above scatter plot, we can see, highest frequency of visits i.e. high reviews per month = where there is less minimum nights stay requirement.
#
#
# * minimum_nights vs availability_365 : most of host set minimum nights stay for 2-200 days in the particular year.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# As from the above visulalization we see that most liked and visited loaction by the customers and hosts are 'Manhattan' . As they liked the location so we need to provide more availability and rooms_types .
# But In bronz , Staten island and Queen location you need to give discount and more affortability to the customers so that they like to move towards these location .
#
#
# *   The maxmimum wide range is of Queen location as you need to modify more things so that the hosts got attracted toward it.
#
# *   Determine the most profitable location for rooms and adjust pricing strategies accordingly.
#
# *   Analyze the customer review data to identify areas of improvement and enhance the hosts experience.
#
# *  Offer flexible deposit options to accommodate different payment preferences of customers.
#
# *  Adjust pricing strategies based on seasonal trends to remain competitive in the industry according to locations.
#
#
# *   Keep tracking of reviews of hosts to understand when demand of rooms and location are high and low. This will help in predicting future demand and making necessary adjustment toward it.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *   In every room type, average highest price is of Manhattan neighbourhood group and highest price is of entire home followed by private and share room. Highest variation of prices is in Staten Island neighbourhood group for entire home.
#
#
# *   The Dataset contain 48858 nos of rows and  16 nos of columns.
#
#
# *   Each observation include information about an individual and unique listing . The 16 columns represent different fields.
#
#
#
#
# *   In Manhattan location ,maximum nights spend and In Bronx location there is minimum nights spend.
#
#
# *   According to the data that i visualize most of the rooms are full which means if we find the room in manhattan as a guest so it is mostly booked.
#
# *   According to the longitude and latitude Queens locations has a larger wide range and staten island location has lowest wide range compared to others.
#
# *   There is a strong relationship between data of number_of_reviews and reviews_per_month.
#
# *  'Manhattan' and 'Brookly' is the location where number of host_id are most active as compared to others.
#
#
# *  The average price as per locations are:
#    *  Manhatten location shows 31.6% of average price.
#
#    *   Brooklyn location shows 20% of average price.
#
#    *   Staten island shows 18.4% of average price
#
#    *   Queen location shows 16% of average price.
#
#    *  Bronx location shows 14% of averageprice.
#
#
#    *   As the maximum average price has taken by manhatten location which means customer loved to visit most and minimum average price has taken by bronx location which means customer visit is low.
#
# *   According to data that i visualize if we want startup a same type of business as per the location and rooms and many more things so i can clearly see that Manhattan is the best place for the business asmost of the host are active.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
